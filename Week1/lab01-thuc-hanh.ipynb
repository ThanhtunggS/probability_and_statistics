# %% [markdown]
# # Bài Thực Hành Lab 01: Khám Phá Cấu Trúc Dữ Liệu Với Python/pandas
# **Học phần:** UET.MAT1052 — Xác suất thống kê (VNU-UET)
# ---
# ### Mục tiêu bài học:
# 1. Đọc và khám phá cấu trúc bảng dữ liệu (, , , , ).
# 2. Xác định đơn vị quan sát và mức độ chi tiết của dữ liệu.
# 3. Phân biệt kiểu lưu trữ máy tính () và bản chất loại biến thống kê.
# 4. Thực hành trên các bộ dữ liệu , , .

# %%
import pandas as pd
import numpy as np
from IPython.display import display

# %% [markdown]
# ## 1. Khảo sát bộ dữ liệu loan50 (IMS 2e)
# Đọc dữ liệu từ file  và kiểm tra 4 biến đại diện: , , , .

# %%
df_loan = pd.read_csv("du-lieu/loan50.csv")
print("Kích thước bảng:", df_loan.shape)
sub_loan = df_loan[["term", "grade", "state", "interest_rate"]].head(5)
display(sub_loan)
print(sub_loan.dtypes)

# %% [markdown]
# ## 2. Khảo sát bộ dữ liệu email50 (OpenIntro 4e)
# Quan sát các biến: , , , .

# %%
df_email = pd.read_csv("du-lieu/email50.csv")
display(df_email[["spam", "cc", "image", "number"]].head(5))

# %% [markdown]
# ## 3. Khảo sát bộ dữ liệu chim cánh cụt Palmer penguins
# Kiểm tra 344 cá thể chim cánh cụt.

# %%
df_penguins = pd.read_csv("du-lieu/penguins.csv")
print("Thông tin cấu trúc:")
df_penguins.info()
print("\nSố lượng theo loài:")
print(df_penguins["species"].value_counts())

# %% [markdown]
# ## 4. Thử thách phản biện W01-PY01
# Phân tích cấu trúc bảng quản lý sinh viên và bản chất biến số.

# %%
mock_data = pd.DataFrame({
    "ma_sinh_vien": [24020001, 24020002, 24020003, 24020004],
    "muc_danh_gia": [1, 2, 5, 4],
    "nganh_hoc": ["CNTT", "KTPM", "KHMT", "DTVT"],
    "gpa": [3.45, 2.80, 3.85, 3.10]
})
display(mock_data)
print(mock_data.dtypes)
