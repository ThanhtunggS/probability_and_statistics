# %% [markdown]
# # BÀI TẬP VỀ NHÀ TUẦN 01 (PROBLEM SET 01)
# ## Môn học: Xác suất Thống kê (UET.MAT1052)
# ### Chủ đề: Vòng đời dữ liệu, Phân loại biến số & Cấu trúc Hàng trong Python
#
# ---
# **Họ và tên sinh viên:** .....................................................
# **Mã số sinh viên (MSV):** .....................................................
# **Lớp học phần:** .....................................................
#
# > **Hướng dẫn:** Thực hiện các bài tập dưới đây bằng cách điền mã nguồn Python vào các ô code tương ứng. Bạn có thể bấm `Shift + Enter` để chạy từng ô và kiểm tra kết quả.

# %% [markdown]
# ### Bài 1: Khởi tạo DataFrame từ dữ liệu khảo sát bạn bè
# Hãy nhập thư viện `pandas` và tạo DataFrame `df_ban_be` từ thông tin của 3 người bạn với các cột:
# - `ho_ten`: Chuỗi ký tự (Họ và tên)
# - `khoang_cach`: Số thực (Khoảng cách từ nhà đến trường theo km)
# - `so_tin_chi`: Số nguyên (Số tín chỉ đăng ký học kỳ này)
# - `phuong_tien`: Chuỗi ký tự (Xe buýt, Xe máy, Đi bộ, Xe đạp)

# %%
import pandas as pd

# TODO: Tạo dictionary chứa dữ liệu của 3 bạn
data = {
    "ho_ten": ["Nguyễn Văn An", "Trần Mai Hương", "Lê Quốc Tú"],
    "khoang_cach": [3.5, 7.2, 1.8],
    "so_tin_chi": [18, 21, 16],
    "phuong_tien": ["Xe buýt", "Xe máy", "Đi bộ"]
}

# TODO: Tạo DataFrame df_ban_be
df_ban_be = pd.DataFrame(data)
display(df_ban_be)
print(df_ban_be.info())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       3 # TODO: Tạo dictionary chứa dữ liệu của 3 bạn
#       4 data = {
#       5     "ho_ten": ["Nguyễn Văn An", "Trần Mai Hương", "Lê Quốc Tú"],
#       6     "khoang_cach": [3.5, 7.2, 1.8],
#       7     "so_tin_chi": [18, 21, 16],
#       8     "phuong_tien": ["Xe buýt", "Xe máy", "Đi bộ"]
#       9 }
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\__init__.py:58
#      55 # let init-time option registration happen
#      56 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 58 from pandas.core.api import (
#      59     # dtype
#      60     ArrowDtype,
#      61     Int8Dtype,
#      62     Int16Dtype,
#      63     Int32Dtype,
#      64     Int64Dtype,
#      65     UInt8Dtype,
#      66     UInt16Dtype,
#      67     UInt32Dtype,
#      68     UInt64Dtype,
#      69     Float32Dtype,
#      70     Float64Dtype,
#      71     CategoricalDtype,
#      72     PeriodDtype,
#      73     IntervalDtype,
#      74     DatetimeTZDtype,
#      75     StringDtype,
#      76     BooleanDtype,
#      77     # missing
#      78     NA,
#      79     isna,
#      80     isnull,
#      81     notna,
#      82     notnull,
#      83     # indexes
#      84     Index,
#      85     CategoricalIndex,
#      86     RangeIndex,
#      87     MultiIndex,
#      88     IntervalIndex,
#      89     TimedeltaIndex,
#      90     DatetimeIndex,
#      91     PeriodIndex,
#      92     IndexSlice,
#      93     # tseries
#      94     NaT,
#      95     Period,
#      96     period_range,
#      97     Timedelta,
#      98     timedelta_range,
#      99     Timestamp,
#     100     date_range,
#     101     bdate_range,
#     102     Interval,
#     103     interval_range,
#     104     DateOffset,
#     105     # conversion
#     106     to_numeric,
#     107     to_datetime,
#     108     to_timedelta,
#     109     # misc
#     110     Flags,
#     111     Grouper,
#     112     factorize,
#     113     unique,
#     114     NamedAgg,
#     115     array,
#     116     Categorical,
#     117     set_eng_float_format,
#     118     Series,
#     119     DataFrame,
#     120 )
#     121 from pandas.core.col import col
#     123 from pandas.core.dtypes.dtypes import SparseDtype
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\api.py:27
#      16 from pandas.core.dtypes.missing import (
#      17     isna,
#      18     isnull,
#      19     notna,
#      20     notnull,
#      21 )
#      23 from pandas.core.algorithms import (
#      24     factorize,
#      25     unique,
#      26 )
# ---> 27 from pandas.core.arrays import Categorical
#      28 from pandas.core.arrays.boolean import BooleanDtype
#      29 from pandas.core.arrays.floating import (
#      30     Float32Dtype,
#      31     Float64Dtype,
#      32 )
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\arrays\__init__.py:1
# ----> 1 from pandas.core.arrays.arrow import ArrowExtensionArray
#       2 from pandas.core.arrays.base import (
#       3     ExtensionArray,
#       4     ExtensionOpsMixin,
#       5     ExtensionScalarOpsMixin,
#       6 )
#       7 from pandas.core.arrays.boolean import BooleanArray
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\arrays\arrow\__init__.py:5
#       1 from pandas.core.arrays.arrow.accessors import (
#       2     ListAccessor,
#       3     StructAccessor,
#       4 )
# ----> 5 from pandas.core.arrays.arrow.array import ArrowExtensionArray
#       7 __all__ = ["ArrowExtensionArray", "ListAccessor", "StructAccessor"]
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\arrays\arrow\array.py:65
#      62 from pandas.core.dtypes.dtypes import DatetimeTZDtype
#      63 from pandas.core.dtypes.missing import isna
# ---> 65 from pandas.core import (
#      66     algorithms as algos,
#      67     missing,
#      68     ops,
#      69     roperator,
#      70 )
#      71 from pandas.core.algorithms import map_array
#      72 from pandas.core.arraylike import OpsMixin
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\ops\__init__.py:24
#      22 from pandas.core.ops.docstrings import make_flex_doc
#      23 from pandas.core.ops.invalid import invalid_comparison
# ---> 24 from pandas.core.ops.mask_ops import (
#      25     kleene_and,
#      26     kleene_or,
#      27     kleene_xor,
#      28 )
#      29 from pandas.core.roperator import (
#      30     radd,
#      31     rand_,
#    (...)     41     rxor,
#      42 )
#      44 # -----------------------------------------------------------------------------
#      45 # constants
#
# File <frozen importlib._bootstrap>:1371, in _find_and_load(name, import_)
#    1369     module = sys.modules.get(name, _NEEDS_LOADING)
#    1370     if module is _NEEDS_LOADING:
# -> 1371         return _find_and_load_unlocked(name, import_)
#    1373 # Optimization: only call _bootstrap._lock_unlock_module() if
#    1374 # module.__spec__._initializing is True.
#    1375 # NOTE: because of this, initializing must be set *before*
#    1376 # putting the new module in sys.modules.
#    1377 _lock_unlock_module(name)
#
# File <frozen importlib._bootstrap>:1342, in _find_and_load_unlocked(name, import_)
#    1340     parent_spec._uninitialized_submodules.append(child)
#    1341 try:
# -> 1342     module = _load_unlocked(spec)
#    1343 finally:
#    1344     if parent_spec:
#
# File <frozen importlib._bootstrap>:938, in _load_unlocked(spec)
#     935             raise ImportError('missing loader', name=spec.name)
#     936         # A namespace package so do nothing.
#     937     else:
# --> 938         spec.loader.exec_module(module)
#     939 except:
#     940     try:
#
# File <frozen importlib._bootstrap_external>:755, in _LoaderBasics.exec_module(self, module)
#     753 def exec_module(self, module):
#     754     """Execute the module."""
# --> 755     code = self.get_code(module.__name__)
#     756     if code is None:
#     757         raise ImportError(f'cannot load module {module.__name__!r} when '
#     758                           'get_code() returns None')
#
# File <frozen importlib._bootstrap_external>:851, in SourceLoader.get_code(self, fullname)
#     849 source_mtime = int(st['mtime'])
#     850 try:
# --> 851     data = self.get_data(bytecode_path)
#     852 except OSError:
#     853     pass
#
# File <frozen importlib._bootstrap_external>:950, in FileLoader.get_data(self, path)
#     948 """Return the data from path as raw bytes."""
#     949 if isinstance(self, (SourceLoader, ExtensionFileLoader)):
# --> 950     with _io.open_code(str(path)) as file:
#     951         return file.read()
#     952 else:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Bài 2: Tính toán các chỉ số thống kê mô tả cơ bản
# 1. Tính khoảng cách trung bình đến trường của các bạn (`mean`).
# 2. Tìm khoảng cách xa nhất (`max`) và gần nhất (`min`).
# 3. Lọc ra danh sách những bạn có khoảng cách từ nhà đến trường lớn hơn 3.0 km.

# %%
# 1. Khoảng cách trung bình
kc_trung_binh = df_ban_be["khoang_cach"].mean()
print(f"Khoảng cách trung bình: {kc_trung_binh:.2f} km")

# 2. Max và Min
kc_max = df_ban_be["khoang_cach"].max()
kc_min = df_ban_be["khoang_cach"].min()
print(f"Xa nhất: {kc_max} km | Gần nhất: {kc_min} km")

# 3. Lọc bạn ở xa hơn 3 km
ban_o_xa = df_ban_be[df_ban_be["khoang_cach"] > 3.0]
display(ban_o_xa)

# %% [markdown]
# ### Bài 3: Khám phá tập dữ liệu thực tế `loan50.csv`
# Tập dữ liệu `loan50.csv` gồm 50 khoản vay từ Lending Club được lưu tại thư mục `du-lieu/loan50.csv`.
# 1. Đọc tệp CSV vào biến `df_loan`.
# 2. Kiểm tra số hàng và số cột của bảng dữ liệu (`df_loan.shape`).
# 3. In ra danh sách các cột và kiểu dữ liệu `dtypes` tương ứng.
# 4. Xác định đâu là biến định lượng liên tục, đâu là biến phân loại thứ bậc.

# %%
import os

# Đường dẫn tới file loan50.csv
csv_path = "../../du-lieu/loan50.csv"
if not os.path.exists(csv_path):
    csv_path = "../03-thuc-hanh-python/du-lieu/loan50.csv"

df_loan = pd.read_csv(csv_path)
print("Kích thước tập dữ liệu (hàng, cột):", df_loan.shape)
print("\n--- 5 hàng đầu tiên ---")
display(df_loan.head())

print("\n--- Kiểu dữ liệu kỹ thuật dtypes ---")
print(df_loan.dtypes)

# %% [markdown]
# ### Bài 4: Chuyển đổi kiểu dữ liệu phân loại thứ bậc (`Categorical Ordinal`)
# Cột `grade` (xếp hạng tín dụng) trong `df_loan` gồm các bậc từ `A` (an toàn nhất) đến `G` (rủi ro nhất).
# Hãy chuyển đổi cột `grade` thành kiểu `category` có thứ tự (`ordered=True`) trong pandas.

# %%
grades_order = ["A", "B", "C", "D", "E", "F", "G"]
df_loan["grade"] = pd.Categorical(df_loan["grade"], categories=grades_order, ordered=True)

print("Kiểu dữ liệu của grade sau khi chuyển:", df_loan["grade"].dtype)
print("Tần số từng bậc xếp hạng:")
print(df_loan["grade"].value_counts().sort_index())
