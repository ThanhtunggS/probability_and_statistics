# %% [markdown]
# # BÀI TẬP THỰC HÀNH PANDAS CƠ BẢN (5 BÀI TẬP)
# **Học phần:** Tự học phân tích dữ liệu & Thống kê với Python
# **Hướng dẫn:** Mỗi bài tập dưới đây đều có đề bài và ô code trống. Bạn hãy tự tay gõ code vào các ô `# TODO` và bấm `Shift + Enter` để chạy kiểm tra kết quả. Dưới mỗi bài đều có kết quả mẫu mong đợi để bạn đối chiếu.
#
# ---
# ### Khởi động: Nạp thư viện cần thiết

# %%
import pandas as pd
from IPython.display import display

print("Môi trường thực hành đã sẵn sàng!")

# %% [markdown]
# ---
# ## Bài 1: Đọc và khảo sát tập dữ liệu sinh viên
# **Tập dữ liệu:** `du-lieu/sinh_vien.csv`
#
# **Yêu cầu:**
# 1. Đọc tệp dữ liệu `du-lieu/sinh_vien.csv` vào biến `df_sv`.
# 2. In kích thước của bảng dữ liệu (số hàng và số cột).
# 3. Hiển thị 5 hàng đầu tiên của bảng bằng hàm `head()` kết hợp `display()`.
# 4. In thông tin tóm tắt cấu trúc bảng bằng hàm `info()`.
#
# *Gợi ý:* Dùng `pd.read_csv(...)`, `df_sv.shape`, `df_sv.head(5)`, `df_sv.info()`.

# %%
# BÀI 1: VIẾT CODE CỦA BẠN DƯỚI ĐÂY
# 1. Đọc file CSV vào biến df_sv:
# TODO

# 2. In số hàng và số cột:
# TODO

# 3. Hiển thị 5 hàng đầu tiên:
# TODO

# 4. In thông tin info():
# TODO

# %% [markdown]
# > **Kết quả mong đợi bài 1:**
# > - Kích thước bảng: `(10, 8)` (10 hàng, 8 cột).
# > - Hiển thị bảng gồm các cột: `ma_sv`, `ho_ten`, `gioi_tinh`, `nganh_hoc`, `gpa`, `so_tin_chi`, `que_quan`, `khoang_cach_km`.
# > - Thông tin `info()` cho thấy `gpa` và `khoang_cach_km` là kiểu `float64`, `so_tin_chi` là kiểu `int64`.

# %% [markdown]
# ---
# ## Bài 2: Thống kê mô tả điểm GPA và khoảng cách đến trường
# Sử dụng bảng dữ liệu `df_sv` từ Bài 1.
#
# **Yêu cầu:**
# 1. Tính điểm GPA trung bình (`mean`) của tất cả sinh viên.
# 2. Tìm điểm GPA cao nhất (`max`) và thấp nhất (`min`).
# 3. Tính khoảng cách trung bình từ nơi ở đến trường (`khoang_cach_km`).
# 4. In các kết quả ra màn hình bằng f-string định dạng 2 chữ số thập phân (`{bien:.2f}`).
#
# *Gợi ý:* `df_sv["gpa"].mean()`, `df_sv["gpa"].max()`, `df_sv["khoang_cach_km"].mean()`.

# %%
# BÀI 2: VIẾT CODE CỦA BẠN DƯỚI ĐÂY
# 1. Tính GPA trung bình, max, min:
# TODO

# 2. Tính khoảng cách trung bình đến trường:
# TODO

# 3. In kết quả:
# TODO

# %% [markdown]
# > **Kết quả mong đợi bài 2:**
# > - GPA trung bình: `3.30`
# > - GPA cao nhất: `3.90` | GPA thấp nhất: `2.75`
# > - Khoảng cách trung bình đến trường: `9.64 km`

# %% [markdown]
# ---
# ## Bài 3: Lọc dữ liệu sinh viên theo điều kiện
# Sử dụng bảng dữ liệu `df_sv`.
#
# **Yêu cầu:**
# 1. Lọc ra danh sách những sinh viên có học lực Giỏi trở lên (`gpa >= 3.6`) và lưu vào biến `sv_xuat_sac`. Hiển thị bảng này.
# 2. Lọc ra danh sách những sinh viên có quê quán ở `"Hà Nội"`.
# 3. Lọc ra những sinh viên thuộc ngành `"KTPM"` (Kỹ thuật phần mềm) HOẶC `"KHMT"` (Khoa học máy tính).
#
# *Gợi ý:*
# - Điều kiện so sánh: `df_sv["gpa"] >= 3.6`
# - Phép HOẶC trong Pandas dùng dấu gạch đứng `|`: `(df_sv["nganh_hoc"] == "KTPM") | (df_sv["nganh_hoc"] == "KHMT")`.

# %%
# BÀI 3: VIẾT CODE CỦA BẠN DƯỚI ĐÂY
# 1. Sinh viên có GPA >= 3.6:
# TODO

# 2. Sinh viên quê Hà Nội:
# TODO

# 3. Sinh viên ngành KTPM hoặc KHMT:
# TODO

# %% [markdown]
# > **Kết quả mong đợi bài 3:**
# > - Câu 1: Có 3 sinh viên (`Trần Thị Bình`, `Hoàng Mai Hoa`, `Vũ Thùy Linh`).
# > - Câu 2: Có 3 sinh viên quê Hà Nội (`Nguyễn Văn An`, `Hoàng Mai Hoa`, `Vũ Thùy Linh`).
# > - Câu 3: Có 5 sinh viên thuộc ngành KTPM hoặc KHMT.

# %% [markdown]
# ---
# ## Bài 4: Đọc và phân tích dữ liệu chi tiêu hàng ngày
# **Tập dữ liệu:** `du-lieu/chi_tieu_hang_ngay.csv`
#
# **Yêu cầu:**
# 1. Đọc tệp dữ liệu `du-lieu/chi_tieu_hang_ngay.csv` vào biến `df_chi_tieu`.
# 2. Hiển thị toàn bộ bảng dữ liệu.
# 3. Tính tổng số tiền đã chi tiêu trong toàn bộ các giao dịch (`sum()`).
# 4. Tìm khoản chi tiêu lớn nhất (`max()`) và nhỏ nhất (`min()`).
# 5. Đếm số lần chi tiêu theo từng danh mục bằng hàm `value_counts()` trên cột `danh_muc`.
#
# *Gợi ý:* `df_chi_tieu["so_tien_vnd"].sum()`, `df_chi_tieu["danh_muc"].value_counts()`.

# %%
# BÀI 4: VIẾT CODE CỦA BẠN DƯỚI ĐÂY
# 1. Đọc file chi_tieu_hang_ngay.csv:
# TODO

# 2. Hiển thị bảng chi tiêu:
# TODO

# 3. Tính tổng, max, min số tiền chi tiêu:
# TODO

# 4. Đếm số lần chi tiêu theo từng danh mục:
# TODO

# %% [markdown]
# > **Kết quả mong đợi bài 4:**
# > - Bảng có 12 giao dịch.
# > - Tổng chi tiêu: `795,000 VNĐ`
# > - Khoản chi lớn nhất: `250,000 VNĐ` (Mua tai nghe học tập) | Nhỏ nhất: `15,000 VNĐ` (Vé xe buýt)
# > - Tần số danh mục: `Ăn uống` xuất hiện 6 lần, `Đi lại` 2 lần, `Giải trí` 2 lần, `Học tập` 1 lần, `Mua sắm` 1 lần.

# %% [markdown]
# ---
# ## Bài 5: Thử thách tổng hợp - Lọc học bổng & Thống kê theo ngành
# Quay trở lại với bảng dữ liệu `df_sv`.
#
# **Yêu cầu:**
# 1. Nhà trường xét học bổng khuyến khích học tập cho những sinh viên thỏa mãn **đồng thời cả 2 điều kiện**:
#    - `gpa >= 3.2`
#    - VÀ số tín chỉ đăng ký `so_tin_chi >= 18`
#    Hãy lọc danh sách các bạn đạt tiêu chuẩn học bổng và lưu vào biến `sv_hoc_bong`.
# 2. Trích xuất bảng kết quả chỉ hiển thị 4 cột: `ma_sv`, `ho_ten`, `gpa`, `so_tin_chi`.
# 3. Đếm số lượng sinh viên trong cả lớp theo từng ngành học (`nganh_hoc.value_counts()`).
#
# *Gợi ý:*
# - Dùng dấu `&` để kết hợp 2 điều kiện: `(df_sv["gpa"] >= 3.2) & (df_sv["so_tin_chi"] >= 18)`
# - Lấy nhiều cột: `sv_hoc_bong[["ma_sv", "ho_ten", "gpa", "so_tin_chi"]]`

# %%
# BÀI 5: VIẾT CODE CỦA BẠN DƯỚI ĐÂY
# 1. Lọc sinh viên đạt tiêu chuẩn học bổng (GPA >= 3.2 và tín chỉ >= 18):
# TODO

# 2. Hiển thị 4 cột thông tin chính của danh sách học bổng:
# TODO

# 3. Đếm số lượng sinh viên theo từng ngành học:
# TODO

# %% [markdown]
# > **Kết quả mong đợi bài 5:**
# > - Có 5 bạn đạt học bổng: `Nguyễn Văn An`, `Trần Thị Bình`, `Phạm Hải Đăng`, `Hoàng Mai Hoa`, `Vũ Thùy Linh`.
# > - Thống kê ngành học cả lớp: `CNTT`: 3 bạn, `KHMT`: 3 bạn, `KTPM`: 2 bạn, `DTVT`: 2 bạn.
